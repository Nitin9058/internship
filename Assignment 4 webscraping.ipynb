# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Question no 1

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")
driver.maximize_window()

# %%
Rank=[]
Video_Name=[]
Artist=[]
Upload_Date=[]
Views=[]

# %%
rank=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
for i in rank[:30]:
    Rank.append(i.text)
    
video_name=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
for i in video_name[:30]:
    Video_Name.append(i.text)
    
artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
for i in artist[:30]:
    Artist.append(i.text)
    
views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
for i in views[:30]:
    Views.append(i.text)
    
upload_date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
for i in upload_date[:30]:
    Upload_Date.append(i.text)

# %%
df_table=pd.DataFrame({'Rank':Rank,'Video_Name':Video_Name,'Artist':Artist,'Views':Views,'Upload_Date':Upload_Date})
df_table
# Out:
#    Rank                                       Video_Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                     "Axel F"[35]
# ...

# %% [markdown]
# # Question no 2

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.bcci.tv/.")
driver.maximize_window()

# %%
view_all=driver.find_element(By.XPATH,"/html/body/div[5]/div/div[2]/div/div[2]/div/div[1]/div[2]/a")
view_all.click()

# %%
match_title=[]
series=[]
place=[]
date=[]
time=[]

# %%
Match_Title=driver.find_elements(By.XPATH,'//div[@class="match-card-middle__inner d-flex justify-content-between"]')
for i in Match_Title:
    match_title.append(i.text)


Series=driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
for i in Series:
    series.append(i.text)
    

Place=driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
for i in Place:
    place.append(i.text)
    

Date=driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')  
for i in Date:
    date.append(i.text)  
    

Time=driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
for i in Time:
    time.append(i.text)

# %%
df=pd.DataFrame({'Match_Title':match_title,'Series':series,'Place':place,'Date':date,'Time':time})
df
# Out:
#             Match_Title     Series          Place         Date         Time
# 0  India\nvs\nAustralia  2nd ODI -  Visakhapatnam  19 MAR 2023  1:30 PM IST
# 1  India\nvs\nAustralia  3rd ODI -        Chennai  22 MAR 2023  1:30 PM IST

# %% [markdown]
# # Question No 3

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("http://statisticstimes.com/")
driver.maximize_window()

# %%
button=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button")
button.click()

# %%
drop_down=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]")
drop_down.click()

# %%
india_economy=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
india_economy.click()

# %%
indian_states=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
indian_states.click()

# %%
rank=[]
state=[]
gsdp_19_20=[]
gsdp_18_19=[]
share_18_19=[]
gdp_billion=[]

# %%
Rank=driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[1]")
for i in Rank[:33]:
    rank.append(i.text)
    
State=driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[2]")
for i in State[:33]:
    state.append(i.text)

GSDP_19_20=driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[3]")
for i in GSDP_19_20[:33]:
    gsdp_19_20.append(i.text)

GSDP_18_19=driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[4]")
for i in GSDP_18_19[:33]:
    gsdp_18_19.append(i.text)

Share_18_19=driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[5]")
for i in Share_18_19[:33]:
    share_18_19.append(i.text)

GDP_billion=driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[6]")
for i in GDP_billion[:33]:
    gdp_billion.append(i.text)

# %%
print(len(rank),len(state),len(gsdp_19_20),len(gsdp_18_19),len(share_18_19),len(gdp_billion))
# Out:
# 33 33 33 33 33 33

# %%
df=pd.DataFrame({'Rank':rank,'State':state,'GSDP_19_20':gsdp_19_20,'GSDP_18_19':gsdp_18_19,'Share_18_19':share_18_19,'GDP_billion':gdp_billion})

# %%
df
# Out:
#    Rank                      State GSDP_19_20 GSDP_18_19 Share_18_19  \
# 0     1                Maharashtra          -  2,632,792      13.94%
# 1     2                 Tamil Nadu  1,845,853  1,630,208       8.63%
# 2     3              Uttar Pradesh  1,687,818  1,584,764       8.39%
# 3     4                    Gujarat          -  1,502,899       7.96%
# 4     5                  Karnataka  1,631,977  1,493,127       7.91%
# 5     6                West Bengal  1,253,832  1,089,898       5.77%
# 6     7                  Rajasthan  1,020,989    942,586       4.99%
# 7     8             Andhra Pradesh    972,782    862,957       4.57%
# 8     9                  Telangana    969,604    861,031       4.56%
# 9    10             Madhya Pradesh    906,672    809,592       4.29%
# 10   11                     Kerala          -    781,653       4.14%
# 11   12                      Delhi    856,112    774,870       4.10%
# 12   13                    Haryana    831,610    734,163       3.89%
# ...

# %% [markdown]
# # Question No 4

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://github.com/")
driver.maximize_window()

# %%
button=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[1]/div[2]/button/span/span/div[1]")
button.click()

# %%
open_source=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
open_source.click()

# %%
trending_option=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
trending_option.click()

# %%
repository_title=[]
repository_description=[]
contributors_count=[]
language_used=[]

# %%
Repository_title=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
for i in Repository_title[0:25]:
    repository_title.append(i.text)
    
Repository_Description=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in Repository_Description[0:25]:
    repository_description.append(i.text)
    
Contributors_Count=driver.find_elements(By.XPATH,'//span[@class="d-inline-block mr-3"]')
for i in Contributors_Count[0:25]:
    contributors_count.append(i.text)
    
Language_Used=driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
for i in Language_Used[0:25]:
    language_used.append(i.text)

# %%
print(len(repository_title),len(repository_description),len(contributors_count),len(language_used))
# Out:
# 25 23 24 24

# %%
df=pd.DataFrame({'Repository_title':repository_title,'Repository_Description':repository_description,'Contributors_Count':contributors_count,'Language_Used':language_used})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13564\4077366305.py in <module>
# ----> 1 df=pd.DataFrame({'Repository_title':repository_title,'Repository_Description':repository_description,'Contributors_Count':contributors_count,'Language_Used':language_used})
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %% [markdown]
# # Question no 5

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https:/www.billboard.com/")
driver.maximize_window()

# %%
button=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button")
button.click()

# %%
charts_option=driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div/div/div/ul/li[1]/h3/a")
charts_option.click()

# %%
billboard_hot_100=driver.find_element(By.XPATH,"/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a")
billboard_hot_100.click()

# %%
song_name=[]
artist_name=[]
last_week_rank=[]
peak_rank=[]
weeks_on_board=[]

# %%
Song_Name=driver.find_elements(By.XPATH,'//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]')
for i in Song_Name:
    song_name.append(i.text)

# %%
print(len(song_name))
# Out:
# 198

# %% [markdown]
# # Question no 6

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")
time.sleep(3)
driver.maximize_window()

# %%
book_name=[]
author_name=[]
volumes_sold=[]
publisher=[]
genre=[]

# %%
Book_Name=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in Book_Name:
    book_name.append(i.text)
Author_Name=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in Author_Name:
    author_name.append(i.text)
Volumes_Sold=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in Volumes_Sold:
    volumes_sold.append(i.text)
Publisher=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in Publisher:
    publisher.append(i.text)
Genre=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in Genre:
    genre.append(i.text)

# %%
df=pd.DataFrame({'Book_Name':book_name,'Author_Name':author_name,'Volumes_Sold':volumes_sold,'Publisher':publisher,'Genre':genre})
df
# Out:
#                                             Book_Name       Author_Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_Sold        Publisher                        Genre
# ...

# %% [markdown]
# # Question no 7

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.imdb.com/list/ls095964455/")
time.sleep(3)
driver.maximize_window()

# %%
series_name=[]
year_span=[]
series_genre=[]
run_time=[]
series_ratings=[]
series_votes=[]

# %%
Series_Name=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/h3/a')
for i in Series_Name[:100]:
    series_name.append(i.text)
Year_Span=driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
for i in Year_Span[:100]:
    year_span.append(i.text)
Series_Genre=driver.find_elements(By.XPATH,'//span[@class="genre"]')
for i in Series_Genre[:100]:
    series_genre.append(i.text)
Run_time=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in Run_time[:100]:
    run_time.append(i.text)
Series_Ratings=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
for i in Series_Ratings[:100]:
    series_ratings.append(i.text)
Series_Votes=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[4]/span[2]')
for i in Series_Votes[:100]:
    series_votes.append(i.text)

# %%
df=pd.DataFrame({'Series_Name':series_name,'Year_Span':year_span,'Series_Genre':series_genre,'Run_time':run_time,'Series_Ratings':series_ratings,'Series_Votes':series_votes})
df
# Out:
#                        Series_Name    Year_Span              Series_Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Series_Ratings Series_Votes
# ...

# %% [markdown]
# # Question no 8

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://archive.ics.uci.edu/")
time.sleep(3)
driver.maximize_window()

# %%
view_all=driver.find_element(By.XPATH,'/html/body/table[2]/tbody/tr/td/span/b/a')
view_all.click()

# %%
dataset_name=[]
data_type=[]
task=[]
attribute_type=[]
no_of_instances=[]
no_of_attribute=[]
year=[]

# %%
Dataset_Name=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
for i in Dataset_Name[0:622]:
    dataset_name.append(i.text)
Data_Type=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
for i in Data_Type[0:622]:
    data_type.append(i.text)
Task=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
for i in Task[0:622]:
    task.append(i.text)
Attribute_Type=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
for i in Attribute_Type[0:622]:
    attribute_type.append(i.text)
No_of_Instances=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
for i in No_of_Instances[0:622]:
    no_of_instances.append(i.text)
No_of_Attribute=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
for i in No_of_Attribute[0:622]:
    no_of_attribute.append(i.text)
Year=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p")
for i in Year[0:622]:
    year.append(i.text)

# %%
df=pd.DataFrame({'Dataset_Name':dataset_name,'Data_Type':data_type,'Task':task,'Attribute_Type':attribute_type,'No_of_Instances':no_of_instances,'No_of_Attribute':no_of_attribute,'Year':year})
df
# Out:
#                                           Dataset_Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data_Type                  Task  \
# 0                    Data Types          Default Task
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                 Multivariate        Classification
# ...

# %% [markdown]
# # Question no 9

# %%
import selenium
import pandas as pd
import time
import warnings
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import requests
import re

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(3)
# Out:
# C:\Users\ser\AppData\Local\Temp\ipykernel_13564\2094894575.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/hr-recruiters-consultants")
time.sleep(3)
driver.maximize_window()

# %%
search_job=driver.find_element(By.XPATH,"//input[@class='sugInp']")
search_job.send_keys('Data science') 

driver.find_element(By.XPATH,"//button[@class='fl qsbSrch blueBtn']").click()

# %%
name=[]
designation=[]
company=[]
skills=[]
location=[]


Name=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div[2]/div/div[2]/div[1]/div[1]/div[1]/div[1]/p/a[1]")
for i in Name[0:50]:
    name.append(i.text)
    

Designation=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div[2]/div/div[2]/div[1]/div[1]/div[1]/div[1]/p/span[1]")
for i in Designation[0:50]:
    designation.append(i.text)
    

Company=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div[2]/div/div[2]/div[1]/div[1]/div[1]/div[1]/p/a[2]")
for i in Company[0:50]:
    company.append(i.text)
    

Skills=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div[2]/div/div[2]/div[1]/div[1]/div[1]/div[2]")
for i in Skills[0:50]:
    skills.append(i.text)
    

Location=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div[2]/div/div[2]/div[1]/div[1]/div[1]/div[1]/p/span[2]")
for i in Location[0:50]:
    location.append(i.text)

# %%
df=pd.DataFrame({'Name':name,'Designation':designation,'Company':company,'Skills':skills,'Location':location})
df
# Out:
#            Name Designation               Company  \
# 0  Aakash Harit  HR Manager  Data Science Network
#
#                                               Skills Location
# 0  Classic ASP Developer, Internet Marketing Prof...    Delhi
